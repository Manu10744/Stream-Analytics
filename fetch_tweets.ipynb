# %%
import os
import json
import requests

CONTENT_TYPE_JSON = "application/json"
TWITTER_API_BASE_URL = "https://api.twitter.com/2/tweets/search/stream"
TWITTER_BEARER_TOKEN = os.environ.get("TWITTER_BEARER_TOKEN", None)

if TWITTER_BEARER_TOKEN is None:
    raise SystemExit("Environment variable 'TWITTER_BEARER_TOKEN' is not set!")

def get_auth_header(bearer_token):
    return {"Authorization": "Bearer {}".format(bearer_token)}

def get_headers_for_rules(bearer_token):
    headers = {
        "Content-type": CONTENT_TYPE_JSON,
        "Authorization": "Bearer {}".format(bearer_token),
    }
    return headers

# %%
# If needed: Check the currently registered filters for the data stream
response = requests.get(f"{TWITTER_API_BASE_URL}/rules",
                       headers=get_auth_header(TWITTER_BEARER_TOKEN))

if response.status_code != 200:
    raise Exception("Can't fetch filter rules (HTTP: {} {}): {}"
                    .format(response.status_code, response.reason, reponse.text))

print("Currently registered filter rules:\n\n {}"
      .format(json.dumps(response.json(), indent=4, sort_keys=True)))
# Out:
# Currently registered filter rules:
#
#  {
#     "data": [
#         {
#             "id": "1378112825051246596",
#             "tag": "coronavirus",
#             "value": "(pandemic OR coronavirus OR covid-19 OR #COVID-19 OR #coronavirus OR #SARSCoV2) -is:retweet"
#         }
#     ],
#     "meta": {
#         "sent": "2021-04-02T22:55:01.887Z"
#     }
# }

# %%
# If needed: Delete filter rules (by ID / IDs) from REST call in cell above
deletion_ids = ["1378111750206337024","1378094676578861056"]
payload = {"delete": {"ids": deletion_ids}}

response = requests.post(f"{TWITTER_API_BASE_URL}/rules",
                        headers=get_auth_header(TWITTER_BEARER_TOKEN),
                        json=payload)

if response.status_code != 200:
    raise Exception("Can't delete rule(s) (HTTP: {} {}): {}"
                    .format(response.status_code, response.reason, response.text))
    
print("Filter rules have been deleted.")
# Out:
# Filter rules have been deleted.

# %%
# Specify filter criteria for the stream
filter_rules = [
    {"value": "(pandemic OR coronavirus OR covid-19 OR #COVID-19 OR #coronavirus OR #SARSCoV2) -is:retweet", 
     "tag": "coronavirus"}
]

payload = {"add": filter_rules}
response = requests.post(f"{TWITTER_API_BASE_URL}/rules",
                        headers=get_headers_for_rules(TWITTER_BEARER_TOKEN),
                        json=payload)

if response.status_code != 201:
    raise Exception("Can't add filter rules (HTTP {} {}):\n {}"
                    .format(response.status_code, response.reason, response.text))

print("Filter Rules for Twitter Stream API have been added.")
# Out:
# Filter Rules for Twitter Stream API have been added.

# %%
# Fetch Tweets from the stream and save as dataset
params = {
    "tweet.fields": "created_at,public_metrics,source,lang",
    "expansions": "author_id"
}

response = requests.get(TWITTER_API_BASE_URL, 
                        headers=get_auth_header(TWITTER_BEARER_TOKEN), 
                        params=params,
                        stream=True)

if response.status_code != 200:
    raise Exception("Can't get stream (HTTP {} {}): {}"
                    .format(response.status_code, response.reason, response.text))

with open("./data/dataset-1.json", "a", encoding="utf-8") as dataset:
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            dataset.write(response_line.decode("utf-8"))
            
            print(json.dumps(json_response, indent=4, ensure_ascii=False, sort_keys=True))
# Out:
# {
#     "data": {
#         "author_id": "83379403",
#         "created_at": "2021-04-02T22:56:41.000Z",
#         "id": "1378119221503266817",
#         "lang": "es",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter for iPhone",
#         "text":

#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "1253872025233502213",
#                 "name": "Myfashion21",
#                 "username": "Myfashion211"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1260048132697665537",
#         "created_at": "2021-04-02T22:56:44.000Z",
#         "id": "1378119235956838400",
#         "lang": "pt",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "covidbrazil",
#         "text": "🇧🇷 Brasil 🇧🇷 : \n\n⚠️ Numero de suspeitas: 1274347\n☢️ Casos confirmados: 12839844\n🪦 Numero de mortes: 325284\n🚑 Recuperados: 11240213\n---------------------------------------\nÚltima atualização 02/04/2021 às 19:56:44\n\n#covid19 #coronavirus #covid19brasil #FiqueEmCasa #FicaEmCasa"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "1260048132697665537",
#                 "name": "Covid Brazil Status",
#                 "username": "CovidBrazil"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "156786461",
#         "created_at": "2021-04-02T22:56:45.000Z",
#         "id": "1378119238112710658",
#         "lang": "en",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter for iPhone",
#         "text": "Am I the only one who wants my personality back, like this year but not April? https://t.co/1kZr77anbt"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "156786461",
#                 "name": "amanda 🌸",
#                 "username": "hypemanda"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1348767273159450625",
#         "created_at": "2021-04-02T22:56:45.000Z",
#         "id": "1378119239752617986",
#         "lang": "en",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter Web App",
#         "text": "@mtgreenee You couldn't wait to politicize the fencing because you thought it would grab you some angry voters. Why don't you crossfit incorrectly and that'll somehow magically stop attacks on the capitol like you claim it protects you from Covid-19?! Resign you un-serious person."
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "1348767273159450625",
#                 "name": "CHANDA FINCH",
#                 "username": "CHANDAFINCH8"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1364844974202703872",
#         "created_at": "2021-04-02T22:56:45.000Z",
#         "id": "1378119239647686656",
#         "lang": "en",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter Web App",
#         "text": "Fuck covidiots https://t.co/uWR5dUBVzy"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "1364844974202703872",
#                 "name": "Neighborhood SuccDem",
#                 "username": "succdem"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "57620858",
#         "created_at": "2021-04-02T22:56:45.000Z",
#         "id": "1378119240427921408",
#         "lang": "pt",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "TweetDeck",
#         "text": "176 votos em Bolonaro para cada brasileiro morto pela Covid-19.\n\n328.206 mortos\n57.796.986 votos"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "57620858",
#                 "name": "In these days of evil presidentes",
#                 "username": "amaral83"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "216174831",
#         "created_at": "2021-04-02T22:56:46.000Z",
#         "id": "1378119241438748679",
#         "lang": "es",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "WordPress.com",
#         "text": "COVID-19: conoce las secuelas luego de superar el virus https://t.co/xmgOJRa8Qo"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "216174831",
#                 "name": "News Qorilab",
#                 "username": "NewsQorilab"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "992159596654579717",
#         "created_at": "2021-04-02T22:56:46.000Z",
#         "id": "1378119241455517698",
#         "lang": "en",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter for Android",
#         "text": "@MisterJones67 @PWrites @LexxDaTurtle @uncle_rjs @bkzproblemchild @DreaVegas WORD... No Cheesy finger tips... We still in a pandemic. 🤣😂 https://t.co/u9zHfNUDDE"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "992159596654579717",
#                 "name": "SoFreshandSoClean",
#                 "username": "Ron51416700"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "182669694",
#         "created_at": "2021-04-02T22:56:46.000Z",
#         "id": "1378119242655092738",
#         "lang": "en",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter Web App",
#         "text": "I would just send that loud no good asshole a shout out.. Hey Matt you still think COVID-19 is a hoax? You still think daddy won the election? Well I think you’re fcked and I will party my ass off.. thanks for the memories https://t.co/h70mgYmxBZ"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "182669694",
#                 "name": "Feyman1",
#                 "username": "feyman1"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "102011794",
#         "created_at": "2021-04-02T22:56:46.000Z",
#         "id": "1378119243024134144",
#         "lang": "ja",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "TwitPanePlus",
#         "text": "#hasumi954\n何度でも言うけど、大宅映子さんのお家はTBSに近いのかもしれないけれど、そんなにCOVID-19を警戒するならリモート出演にすれば、慎重な行動を取る様子がわずかでもアピールになるのに。"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "102011794",
#                 "name": "たはらありみ",
#                 "username": "a_rimit"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1329208027421974528",
#         "created_at": "2021-04-02T22:56:46.000Z",
#         "id": "1378119244391530497",
#         "lang": "und",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter for iPhone",
#         "text": "@CorpusDelicti01 @jmbenson1491 @chuckwoolery @JackPosobiec https://t.co/q8A5dzl5O0"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "1329208027421974528",
#                 "name": "Taro",
#                 "username": "005Qin"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1048395856616062978",
#         "created_at": "2021-04-02T22:56:46.000Z",
#         "id": "1378119244802580486",
#         "lang": "en",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter for iPhone",
#         "text": "@KymC1019 If the CDC was worth a damn we wouldn’t be in the mess. But how Ironic they already knew about Covid-19 and knew it was in Wuhan labs. They have the full genetic makeup of the virus."
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "1048395856616062978",
#                 "name": "Ricard J",
#                 "username": "USNAVY4EVA"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1271427750868463618",
#         "created_at": "2021-04-02T22:56:46.000Z",
#         "id": "1378119244861296640",
#         "lang": "und",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter for Android",
#         "text": "@ManuJo152\n#LaPrevenciónEsClave\n@Mippcivzla @NicolasMaduro https://t.co/xivwtEhlfe"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "1271427750868463618",
#                 "name": "Manuel Jo",
#                 "username": "ManuJo152"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "14629400",
#         "created_at": "2021-04-02T22:56:46.000Z",
#         "id": "1378119245251420165",
#         "lang": "und",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter for iPad",
#         "text": "!!!! https://t.co/mX0XNS68de"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "14629400",
#                 "name": "Rick Conrad",
#                 "username": "rickconrad"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1271427750868463618",
#         "created_at": "2021-04-02T22:56:47.000Z",
#         "id": "1378119247969316868",
#         "lang": "und",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter for Android",
#         "text": "@ManuJo152\n#LaPrevenciónEsClave\n@Mippcivzla @NicolasMaduro https://t.co/YxDGrh9hMU"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "1271427750868463618",
#                 "name": "Manuel Jo",
#                 "username": "ManuJo152"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1096022358995931136",
#         "created_at": "2021-04-02T22:56:48.000Z",
#         "id": "1378119251014352897",
#         "lang": "en",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter for Android",
#         "text": "@dino_melaye He did not learn to equip our hospitals from the last year pandemic, I wish he had his share of covid 19 last year personally."
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "1096022358995931136",
#                 "name": "Kennedy Onyekezini",
#                 "username": "KOnyekezini"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1277836845561200641",
#         "created_at": "2021-04-02T22:56:48.000Z",
#         "id": "1378119253799227392",
#         "lang": "en",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter Web App",
#         "text": "Excited to be going back to USH to work! Literally during the pandemic I took a lot of different jobs but USH has always been my favorite place to work at so I’m just excited to be back!!"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "1277836845561200641",
#                 "name": "america 🇲🇽",
#                 "username": "Lilmuurr"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "3097131710",
#         "created_at": "2021-04-02T22:56:48.000Z",
#         "id": "1378119253774135296",
#         "lang": "en",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter for Android",
#         "text": "@Vegas_Vampire @eatinglasvegas Many drivers who left during the start of the pandemic never came back. Some collected unemployment others focused on their other jobs."
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "3097131710",
#                 "name": "John Car",
#                 "username": "jcarpro"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1372948776235712522",
#         "created_at": "2021-04-02T22:56:49.000Z",
#         "id": "1378119254852141057",
#         "lang": "en",
#         "public_metrics": {
#             "like_count": 1,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter for iPhone",
#         "text": "we are very sorry for our inactivity, members from our team got the COVID-19. We will try to provide the best informations ! Thank you !"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "1372948776235712522",
#                 "name": "OMEGA X Charts & Data ΩX",
#                 "username": "ChartsOmegaX"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "2502543817",
#         "created_at": "2021-04-02T22:56:49.000Z",
#         "id": "1378119254998872064",
#         "lang": "in",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter for Android",
#         "text": "Sementara penyuntikan vaksin Covid-19 dosis 2 sampai hari ini sudah mencapai 3.867.566 #StrategiPemulihanNegeri #5y https://t.co/8uE0qUsQ4V"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "2502543817",
#                 "name": "Matías Rubio",
#                 "username": "MatiasRubio213"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "934044199061778432",
#         "created_at": "2021-04-02T22:56:49.000Z",
#         "id": "1378119256185913344",
#         "lang": "fr",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "source": "Twitter Web App",
#         "text": "ils vont reprendre les concerts 😭 https://t.co/4TUzFMmCSD"
#     },
#     "includes": {
#         "users": [
#             {
#                 "id": "934044199061778432",
#                 "name": "Bella 🇫🇷⭐⭐",
#                 "username": "SoDakotaBella"
#             }
#         ]
#     },
#     "matching_rules": [
#         {
#             "id": 1378112825051246596,
#             "tag": "coronavirus"
#         }
#     ]
# }
